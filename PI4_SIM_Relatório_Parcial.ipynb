# %% [markdown]
# <a href="https://colab.research.google.com/github/Navegantes-UNIVESP/PI4_SIM/blob/main/PI4_SIM_Relat%C3%B3rio_Parcial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dados do SIM (Sistema de Informações de Mortalidade)
# Fonte: https://opendatasus.saude.gov.br/dataset/sim-2020-2021

# %%
import pandas as pd

url="https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIM/DO21OPEN.csv"
df = pd.read_csv(url, sep=";")
# Out:
# <ipython-input-1-f8fe2b5ed14e>:4: DtypeWarning: Columns (65,82,83) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url, sep=";")

# %%
#Mostrar todas as colunas
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    contador  ORIGEM  TIPOBITO   DTOBITO  HORAOBITO  NATURAL  CODMUNNATU  \
# 0         1       1         2  13042021      611.0    831.0    317190.0
# 1         2       1         2  13042021      200.0    841.0    412730.0
# 2         3       1         2  12042021     2238.0    811.0    110020.0
# 3         4       1         2  25022021     2235.0    811.0    110020.0
# 4         5       1         2  12042021     1430.0    811.0    110004.0
#
#        DTNASC  IDADE  SEXO  RACACOR  ESTCIV  ESC  ESC2010  SERIESCFAL  \
# 0  25051955.0  465.0     1      4.0     2.0  NaN      NaN         NaN
# 1   8091956.0  464.0     1      4.0     1.0  3.0      2.0         NaN
# 2   7121972.0  448.0     1      2.0     2.0  5.0      5.0         NaN
# 3  12061964.0  456.0     2      4.0     2.0  4.0      3.0         3.0
# 4   6041983.0  438.0     2      4.0     NaN  NaN      NaN         NaN
#
#        OCUP  CODMUNRES  LOCOCOR   CODESTAB  CODMUNOCOR  IDADEMAE  ESCMAE  \
# ...

# %%
df.shape
# Out:
# (1855622, 86)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of          contador  ORIGEM  TIPOBITO   DTOBITO  HORAOBITO  NATURAL  CODMUNNATU  \
# 0               1       1         2  13042021      611.0    831.0    317190.0
# 1               2       1         2  13042021      200.0    841.0    412730.0
# 2               3       1         2  12042021     2238.0    811.0    110020.0
# 3               4       1         2  25022021     2235.0    811.0    110020.0
# 4               5       1         2  12042021     1430.0    811.0    110004.0
# ...           ...     ...       ...       ...        ...      ...         ...
# 1855617   1855618       1         2   7122021        NaN    813.0    130030.0
# 1855618   1855619       1         2  26102021        NaN    813.0    130250.0
# 1855619   1855620       1         2   4112021      200.0    813.0    130140.0
# 1855620   1855621       1         1   1122021     1000.0    813.0    130270.0
# 1855621   1855622       1         2  11102021        NaN      NaN         NaN
#
# ...

# %%
df_idade = df["IDADE"]

# %%
df_idade.unique()
# Out:
# array([465., 464., 448., 456., 438., 467., 471., 487., 473., 496., 463.,
#        460., 466., 474., 455., 441., 462., 485., 495., 478., 476., 484.,
#        483., 461., 458., 459., 482., 486., 493., 470., 469., 477., 489.,
#        435., 472., 457., 500., 418., 454., 453., 433., 428., 440., 449.,
#        481., 468., 490., 447., 446., 444., 480.,  nan, 445., 439., 498.,
#        443., 214., 452., 451., 436., 424., 201., 488., 479., 492., 491.,
#        475., 427., 442., 494., 501., 408., 430., 420., 434., 103., 499.,
#        497., 412., 205., 450., 302., 431., 425., 206., 504., 101., 437.,
#        429., 203., 303., 311.,  45., 102.,  32., 426., 414., 502., 503.,
#        208., 217., 432., 310., 305., 213., 301.,  44., 421., 419., 422.,
#        407., 415., 423., 306., 403., 401., 209., 404., 413., 410., 417.,
#        999., 204., 308., 221., 111., 416., 409., 210.,  20., 515., 505.,
#        211., 411., 402., 207., 506., 215., 307., 202., 227.,  25., 106.,
# ...

# %%
df_idade["IDADE"]%400

# %%
df_idade_10 = df_idade.head(10)
df_idade_10
# Out:
# 0    465.0
# 1    464.0
# 2    448.0
# 3    456.0
# 4    438.0
# 5    467.0
# 6    471.0
# 7    487.0
# 8    473.0
# 9    496.0
# Name: IDADE, dtype: float64

# %%
display(df.loc[df["IDADE"]>=500])
# Out:
#          contador  ORIGEM  TIPOBITO   DTOBITO  HORAOBITO  NATURAL  CODMUNNATU  \
# 60             61       1         2   2042021     2350.0    852.0    521380.0
# 168           169       1         2  16062021     1930.0    831.0    315780.0
# 243           244       1         2  22062021     1720.0    821.0    211250.0
# 374           375       1         2  27062021     1130.0    831.0    311610.0
# 514           515       1         2  10022021     1352.0    831.0    313600.0
# ...           ...     ...       ...       ...        ...      ...         ...
# 1855260   1855261       2         2  17122021     1520.0    833.0    330480.0
# 1855390   1855391       2         2  18122021        NaN    833.0    330000.0
# 1855402   1855403       2         2  10122021      931.0      NaN         NaN
# 1855461   1855462       2         2  21122021        NaN    800.0         NaN
# 1855468   1855469       2         2   9122021      700.0      NaN         NaN
#
# ...

# %%
df[df["IDADE"]>=400]
# Out:
#          contador  ORIGEM  TIPOBITO   DTOBITO  HORAOBITO  NATURAL  CODMUNNATU  \
# 60             61       1         2   2042021     2350.0    852.0    521380.0
# 168           169       1         2  16062021     1930.0    831.0    315780.0
# 243           244       1         2  22062021     1720.0    821.0    211250.0
# 374           375       1         2  27062021     1130.0    831.0    311610.0
# 514           515       1         2  10022021     1352.0    831.0    313600.0
# ...           ...     ...       ...       ...        ...      ...         ...
# 1855260   1855261       2         2  17122021     1520.0    833.0    330480.0
# 1855390   1855391       2         2  18122021        NaN    833.0    330000.0
# 1855402   1855403       2         2  10122021      931.0      NaN         NaN
# 1855461   1855462       2         2  21122021        NaN    800.0         NaN
# 1855468   1855469       2         2   9122021      700.0      NaN         NaN
#
# ...

# %%
df_idade_anos = df[(df["IDADE"]>=400) & (df["IDADE"]<500)]
df_idade_anos
# Out:
# Empty DataFrame
# Columns: [contador, ORIGEM, TIPOBITO, DTOBITO, HORAOBITO, NATURAL, CODMUNNATU, DTNASC, IDADE, SEXO, RACACOR, ESTCIV, ESC, ESC2010, SERIESCFAL, OCUP, CODMUNRES, LOCOCOR, CODESTAB, CODMUNOCOR, IDADEMAE, ESCMAE, ESCMAE2010, SERIESCMAE, OCUPMAE, QTDFILVIVO, QTDFILMORT, GRAVIDEZ, SEMAGESTAC, GESTACAO, PARTO, OBITOPARTO, PESO, TPMORTEOCO, OBITOGRAV, OBITOPUERP, ASSISTMED, EXAME, CIRURGIA, NECROPSIA, LINHAA, LINHAB, LINHAC, LINHAD, LINHAII, CAUSABAS, CB_PRE, COMUNSVOIM, DTATESTADO, CIRCOBITO, ACIDTRAB, FONTE, NUMEROLOTE, DTINVESTIG, DTCADASTRO, ATESTANTE, STCODIFICA, CODIFICADO, VERSAOSIST, VERSAOSCB, FONTEINV, DTRECEBIM, ATESTADO, DTRECORIGA, OPOR_DO, CAUSAMAT, ESCMAEAGR1, ESCFALAGR1, STDOEPIDEM, STDONOVA, DIFDATA, NUDIASOBCO, DTCADINV, TPOBITOCOR, DTCONINV, FONTES, TPRESGINFO, TPNIVELINV, DTCADINF, MORTEPARTO, DTCONCASO, ALTCAUSA, CAUSABAS_O, TPPOS, TP_ALTERA, CB_ALT]
# Index: []

# %%
df.loc[(df["IDADE"]>400) & (df["IDADE"]<500), "IDADE"] = df["IDADE"]%400
df.IDADE.unique()
# Out:
# array([ 65.,  64.,  48.,  56.,  38.,  67.,  71.,  87.,  73.,  96.,  63.,
#         60.,  66.,  74.,  55.,  41.,  62.,  85.,  95.,  78.,  76.,  84.,
#         83.,  61.,  58.,  59.,  82.,  86.,  93.,  70.,  69.,  77.,  89.,
#         35.,  72.,  57., 500.,  18.,  54.,  53.,  33.,  28.,  40.,  49.,
#         81.,  68.,  90.,  47.,  46.,  44.,  80.,  nan,  45.,  39.,  98.,
#         43., 214.,  52.,  51.,  36.,  24., 201.,  88.,  79.,  92.,  91.,
#         75.,  27.,  42.,  94., 501.,   8.,  30.,  20.,  34., 103.,  99.,
#         97.,  12., 205.,  50., 302.,  31.,  25., 206., 504., 101.,  37.,
#         29., 203., 303., 311., 102.,  32.,  26.,  14., 502., 503., 208.,
#        217., 310., 305., 213., 301.,  21.,  19.,  22.,   7.,  15.,  23.,
#        306.,   3.,   1., 209.,   4.,  13.,  10.,  17., 999., 204., 308.,
#        221., 111.,  16.,   9., 210., 515., 505., 211.,  11.,   2., 207.,
#        506., 215., 307., 202., 227., 106., 105., 220.,   5., 200., 118.,
# ...
